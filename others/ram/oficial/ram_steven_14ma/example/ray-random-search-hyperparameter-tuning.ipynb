# %%
# the warnings are total BS e.g: The name reduce_all is deprecated. Please use reduce_all instead 
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
import time

import tensorflow as tf
import numpy as np
import ray

from sklearn.model_selection import train_test_split

from model.ram import RecurrentAttentionModel

from data.augmented_mnist import minibatcher
from data.augmented_mnist import get_mnist
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0417 12:53:52.097383 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
#
# W0417 12:53:52.099782 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
#
# W0417 12:53:52.100424 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
#
# W0417 12:53:52.153022 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:191: The name Tensor is deprecated. Please use Tensor instead.
#
# W0417 12:53:52.154199 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:325: The name register_tensor_conversion_function is deprecated. Please use register_tensor_conversion_function instead.
#
# W0417 12:53:52.167250 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/dense_variational_v2.py:151: The name convert_to_tensor is deprecated. Please use convert_to_tensor instead.
#
# W0417 12:53:52.171181 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:89: The name keras.layers.Lambda is deprecated. Please use keras.layers.Lambda instead.
#
# W0417 12:53:52.172121 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:1136: The name keras.regularizers.Regularizer is deprecated. Please use keras.regularizers.Regularizer instead.
#
# W0417 12:53:52.172914 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:1883: The name keras.utils.get_custom_objects is deprecated. Please use keras.utils.get_custom_objects instead.
#
# W0417 12:53:52.173984 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/initializers.py:27: The name keras.initializers.Initializer is deprecated. Please use keras.initializers.Initializer instead.
#
# W0417 12:53:52.199207 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/optimizer/sgld.py:34: The name keras.optimizers.Optimizer is deprecated. Please use keras.optimizers.Optimizer instead.
#
# W0417 12:53:52.201455 140588183955200 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/positive_semidefinite_kernels/internal/util.py:89: The name custom_gradient is deprecated. Please use custom_gradient instead.
#
# W0417 12:53:52.212678 140588183955200 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:4: The name keras.Model is deprecated. Please use keras.models.Model instead.
#
# W0417 12:53:52.214348 140588183955200 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:5: The name keras.layers.LSTMCell is deprecated. Please use keras.layers.LSTMCell instead.

# %%
(X_train, y_train),(X_test, y_test) = get_mnist(True, True, False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

print(X_train.shape, y_train.shape, np.max(X_train), np.min(X_train))
print(X_val.shape, y_val.shape, np.max(X_val), np.min(X_val))
print(X_test.shape, y_test.shape, np.max(X_test), np.min(X_test))
# Out:
# W0417 12:53:52.415025 140588183955200 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/data/augmented_mnist.py:64: The name keras.datasets.mnist.load_data is deprecated. Please use keras.datasets.mnist.load_data instead.
#
# W0417 12:53:52.838382 140588183955200 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/data/augmented_mnist.py:78: The name keras.utils.to_categorical is deprecated. Please use keras.utils.to_categorical instead.
# (45000, 28, 28, 1) (45000, 10) 1.0 0.0
# (15000, 28, 28, 1) (15000, 10) 1.0 0.0
# (10000, 28, 28, 1) (10000, 10) 1.0 0.0

# %%
@ray.remote
def train(hyperparameter, X_train, y_train, X_val, y_val):
    ram = RecurrentAttentionModel(time_steps=7,
                                  n_glimpses=1, 
                                  glimpse_size=8,
                                  num_classes=10,
                                  max_gradient_norm=5.0,
                                  std=hyperparameter["std"])
    optimizer = tf.keras.optimizers.Adam(hyperparameter["learning_rate"])
    for e in range(10):
        # trainings step
        batcher = minibatcher(X_train, y_train, 500, True)
        for X, y in batcher:
            with tf.GradientTape() as tape:
                logits = ram(X)
                hybrid_loss, _, _, _ = ram.hybrid_loss(logits, y)

                gradients = tape.gradient(hybrid_loss, ram.trainable_variables)
                optimizer.apply_gradients(zip(gradients, ram.trainable_variables))

        # testing step
        batcher = minibatcher(X_val, y_val, 500, True)
        accuracys = []
        for X, y in batcher:
            logits = ram(X)
            accuracy, _, _ = ram.predict(logits, y)
            accuracy = accuracy.numpy()
            accuracys.append(accuracy)
    return np.mean(accuracys)

# %%
def generate_hyperparameters():
    # Randomly choose values for the hyperparameters.
    return {"learning_rate": 10 ** -np.random.uniform(0, 8),
            "std": 10 ** -np.random.uniform(0, 2)}

# %%
ray.init()

# Launch a experiments.
remaining_ids = []
hyperparameters = generate_hyperparameters()
remaining_ids.append(train.remote(hyperparameters, X_train, y_train, X_val, y_val))

# Whenever a new experiment finishes, print the value and start a new
# experiment.
for i in range(10):
    ready_ids, remaining_ids = ray.wait(remaining_ids, num_returns=1)
    accuracy = ray.get(ready_ids[0])
    print("Accuracy is {}".format(accuracy), "Hyperparameter:", hyperparameters)
    # Start a new experiment.
    hyperparameters = generate_hyperparameters()
    remaining_ids.append(train.remote(hyperparameters, X_train, y_train, X_val, y_val))
# Out:
# 2019-04-17 12:53:52,971	INFO node.py:423 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-04-17_12-53-52_9743/logs.
# 2019-04-17 12:53:53,098	INFO services.py:363 -- Waiting for redis server at 127.0.0.1:61304 to respond...
# 2019-04-17 12:53:53,226	INFO services.py:363 -- Waiting for redis server at 127.0.0.1:16930 to respond...
# 2019-04-17 12:53:53,229	INFO services.py:760 -- Starting Redis shard with 10.0 GB max memory.
# 2019-04-17 12:53:53,269	WARNING services.py:1236 -- Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# 2019-04-17 12:53:53,270	WARNING services.py:1261 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 67108864 bytes available. This may slow down performance! You may be able to free up space by deleting files in /dev/shm or terminating any running plasma_store_server processes. If you are inside a Docker container, you may need to pass an argument with the flag '--shm-size' to 'docker run'.
# 2019-04-17 12:53:53,271	INFO services.py:1384 -- Starting the Plasma object store with 20.0 GB memory using /tmp.
# (pid=9805) WARNING: Logging before flag parsing goes to stderr.
# (pid=9805) W0417 12:53:56.630001 140654403319552 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9805)
# (pid=9805) W0417 12:53:56.630887 140654403319552 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9805)
# (pid=9805) W0417 12:53:56.631088 140654403319552 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9805)
# (pid=9795) WARNING: Logging before flag parsing goes to stderr.
# (pid=9795) W0417 12:53:56.649762 140588611417856 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9795)
# (pid=9795) W0417 12:53:56.650623 140588611417856 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9795)
# (pid=9795) W0417 12:53:56.650809 140588611417856 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9795)
# (pid=9806) WARNING: Logging before flag parsing goes to stderr.
# (pid=9806) W0417 12:53:56.680728 139694948947712 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9806)
# (pid=9806) W0417 12:53:56.681679 139694948947712 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9806)
# (pid=9806) W0417 12:53:56.681913 139694948947712 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9806)
# (pid=9805) W0417 12:53:56.770115 140654403319552 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:191: The name Tensor is deprecated. Please use Tensor instead.
# (pid=9805)
# (pid=9805) W0417 12:53:56.770871 140654403319552 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:325: The name register_tensor_conversion_function is deprecated. Please use register_tensor_conversion_function instead.
# (pid=9805)
# (pid=9795) W0417 12:53:56.775200 140588611417856 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:191: The name Tensor is deprecated. Please use Tensor instead.
# (pid=9795)
# (pid=9795) W0417 12:53:56.776085 140588611417856 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:325: The name register_tensor_conversion_function is deprecated. Please use register_tensor_conversion_function instead.
# (pid=9795)
# (pid=9804) WARNING: Logging before flag parsing goes to stderr.
# (pid=9804) W0417 12:53:56.731784 140085473634048 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9804)
# (pid=9804) W0417 12:53:56.732704 140085473634048 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9804)
# (pid=9804) W0417 12:53:56.732895 140085473634048 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9804)
# (pid=9799) WARNING: Logging before flag parsing goes to stderr.
# (pid=9799) W0417 12:53:56.809486 140358321325824 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9799)
# (pid=9799) W0417 12:53:56.810417 140358321325824 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9799)
# (pid=9799) W0417 12:53:56.810601 140358321325824 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9799)
# (pid=9803) WARNING: Logging before flag parsing goes to stderr.
# (pid=9803) W0417 12:53:56.820398 139777028392704 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=
deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/positive_semidefinite_kernels/internal/util.py:89: The name custom_gradient is deprecated. Please use custom_gradient instead.
# (pid=9798)
# (pid=9798) W0417 12:53:57.062705 140558623917824 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:4: The name keras.Model is deprecated. Please use keras.models.Model instead.
# (pid=9798)
# (pid=9798) W0417 12:53:57.063363 140558623917824 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:5: The name keras.layers.LSTMCell is deprecated. Please use keras.layers.LSTMCell instead.
# (pid=9798)
# (pid=9809) WARNING: Logging before flag parsing goes to stderr.
# (pid=9809) W0417 12:53:57.052860 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9809)
# (pid=9809) W0417 12:53:57.053642 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9809)
# (pid=9809) W0417 12:53:57.053817 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9809)
# (pid=9808) WARNING: Logging before flag parsing goes to stderr.
# (pid=9808) W0417 12:53:57.058155 139669623564032 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/math/root_search.py:51: The name reduce_all is deprecated. Please use reduce_all instead.
# (pid=9808)
# (pid=9808) W0417 12:53:57.058746 139669623564032 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:412: The name nn.relu is deprecated. Please use nn.relu instead.
# (pid=9808)
# (pid=9808) W0417 12:53:57.058848 139669623564032 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py:529: The name keras.layers.Layer is deprecated. Please use keras.layers.Layer instead.
# (pid=9808)
# (pid=9802) W0417 12:53:57.111880 140130090014464 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:4: The name keras.Model is deprecated. Please use keras.models.Model instead.
# (pid=9802)
# (pid=9802) W0417 12:53:57.112790 140130090014464 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:5: The name keras.layers.LSTMCell is deprecated. Please use keras.layers.LSTMCell instead.
# (pid=9802)
# (pid=9800) W0417 12:53:57.107203 140483705661184 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/optimizer/sgld.py:34: The name keras.optimizers.Optimizer is deprecated. Please use keras.optimizers.Optimizer instead.
# (pid=9800)
# (pid=9800) W0417 12:53:57.109797 140483705661184 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/positive_semidefinite_kernels/internal/util.py:89: The name custom_gradient is deprecated. Please use custom_gradient instead.
# (pid=9800)
# (pid=9800) W0417 12:53:57.119554 140483705661184 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:4: The name keras.Model is deprecated. Please use keras.models.Model instead.
# (pid=9800)
# (pid=9800) W0417 12:53:57.120102 140483705661184 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:5: The name keras.layers.LSTMCell is deprecated. Please use keras.layers.LSTMCell instead.
# (pid=9800)
# (pid=9800) W0417 12:53:57.152854 140483886868224 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/layers.py:4: The name random.uniform is deprecated. Please use random.uniform instead.
# (pid=9800)
# (pid=9800) 2019-04-17 12:53:57.154372: I tensorflow/stream_executor/platform/default/dso_loader.cc:43] Successfully opened dynamic library libcuda.so.1
# (pid=9809) W0417 12:53:57.118376 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:191: The name Tensor is deprecated. Please use Tensor instead.
# (pid=9809)
# (pid=9809) W0417 12:53:57.118819 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:325: The name register_tensor_conversion_function is deprecated. Please use register_tensor_conversion_function instead.
# (pid=9809)
# (pid=9809) W0417 12:53:57.129622 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/dense_variational_v2.py:151: The name convert_to_tensor is deprecated. Please use convert_to_tensor instead.
# (pid=9809)
# (pid=9809) W0417 12:53:57.131739 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:89: The name keras.layers.Lambda is deprecated. Please use keras.layers.Lambda instead.
# (pid=9809)
# (pid=9809) W0417 12:53:57.132022 140282903758592 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:1136: The name keras.regularizers.Regularizer is deprecated. Please use keras.regularizers.Regularizer instead.
# (pid=9809)
# ...
# (pid=10134)
# (pid=10134) W0417 12:53:57.433289 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:191: The name Tensor is deprecated. Please use Tensor instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.433722 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/edward2/random_variable.py:325: The name register_tensor_conversion_function is deprecated. Please use register_tensor_conversion_function instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.443779 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/dense_variational_v2.py:151: The name convert_to_tensor is deprecated. Please use convert_to_tensor instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.445849 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:89: The name keras.layers.Lambda is deprecated. Please use keras.layers.Lambda instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.446104 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:1136: The name keras.regularizers.Regularizer is deprecated. Please use keras.regularizers.Regularizer instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.446398 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/distribution_layer.py:1883: The name keras.utils.get_custom_objects is deprecated. Please use keras.utils.get_custom_objects instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.446709 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/layers/initializers.py:27: The name keras.initializers.Initializer is deprecated. Please use keras.initializers.Initializer instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.463688 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/optimizer/sgld.py:34: The name keras.optimizers.Optimizer is deprecated. Please use keras.optimizers.Optimizer instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.466074 140415362680576 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow_probability/python/positive_semidefinite_kernels/internal/util.py:89: The name custom_gradient is deprecated. Please use custom_gradient instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.475478 140415362680576 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:4: The name keras.Model is deprecated. Please use keras.models.Model instead.
# (pid=10134)
# (pid=10134) W0417 12:53:57.476043 140415362680576 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:5: The name keras.layers.LSTMCell is deprecated. Please use keras.layers.LSTMCell instead.
# (pid=10134)
# (pid=9800) 2019-04-17 12:53:57.648586: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1485] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# (pid=9800) W0417 12:53:57.873097 140483886868224 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name random.normal is deprecated. Please use random.normal instead.
# (pid=9800)
# (pid=9800) W0417 12:53:58.541207 140483886868224 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name nn.softmax_cross_entropy_with_logits is deprecated. Please use nn.softmax_cross_entropy_with_logits instead.
# (pid=9800)
# (pid=9800) W0417 12:53:58.541579 140483886868224 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name nn.softmax is deprecated. Please use nn.softmax instead.
# (pid=9800)
# Accuracy is 0.10906665772199631 Hyperparameter: {'learning_rate': 8.308555042725081e-05, 'std': 0.07800447885531216}
# (pid=9801) W0417 12:56:30.873432 140635223062272 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/layers.py:4: The name random.uniform is deprecated. Please use random.uniform instead.
# (pid=9801)
# (pid=9801) 2019-04-17 12:56:30.875420: I tensorflow/stream_executor/platform/default/dso_loader.cc:43] Successfully opened dynamic library libcuda.so.1
# (pid=9801) 2019-04-17 12:56:30.881215: E tensorflow/stream_executor/cuda/cuda_driver.cc:320] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# (pid=9801) 2019-04-17 12:56:30.881254: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:166] retrieving CUDA diagnostic information for host: 68fd474b8e08
# (pid=9801) 2019-04-17 12:56:30.881285: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:173] hostname: 68fd474b8e08
# (pid=9801) 2019-04-17 12:56:30.881365: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 410.104.0
# (pid=9801) 2019-04-17 12:56:30.881384: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 410.104.0
# (pid=9801) 2019-04-17 12:56:30.881391: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:308] kernel version seems to match DSO: 410.104.0
# (pid=9801) 2019-04-17 12:56:30.881594: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# (pid=9801) 2019-04-17 12:56:30.909464: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3600145000 Hz
# (pid=9801) 2019-04-17 12:56:30.910428: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2e56fe0 executing computations on platform Host. Devices:
# (pid=9801) 2019-04-17 12:56:30.910475: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# (pid=9801) W0417 12:56:30.916368 140635223062272 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/layers.py:20: The name keras.layers.BatchNormalization is deprecated. Please use keras.layers.BatchNormalization instead.
# (pid=9801)
# (pid=9801) W0417 12:56:30.936599 140635223062272 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:61: The name keras.layers.Dense is deprecated. Please use keras.layers.Dense instead.
# (pid=9801)
# (pid=9801) W0417 12:56:31.064034 140635223062272 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:314: The name image.extract_glimpse is deprecated. Please use image.extract_glimpse instead.
# (pid=9801)
# (pid=9801) W0417 12:56:31.065093 140635223062272 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:320: The name image.resize is deprecated. Please use image.resize instead.
# (pid=9801)
# (pid=9801) W0417 12:56:31.065177 140635223062272 deprecation_wrapper.py:76] From /tf/workspace/recurrent-visual-attention-model/model/ram.py:322: The name image.ResizeMethod is deprecated. Please use image.ResizeMethod instead.
# (pid=9801)
# (pid=9801) W0417 12:56:31.092403 140635223062272 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name nn.conv2d is deprecated. Please use nn.conv2d instead.
# (pid=9801)
# (pid=9801) W0417 12:56:31.092905 140635223062272 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name nn.bias_add is deprecated. Please use nn.bias_add instead.
# (pid=9801)
# (pid=9801) 2019-04-17 12:56:31.352310: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1485] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# (pid=9801) W0417 12:56:31.580359 140635223062272 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name random.normal is deprecated. Please use random.normal instead.
# (pid=9801)
# (pid=9801) W0417 12:56:32.258027 140635223062272 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name nn.softmax_cross_entropy_with_logits is deprecated. Please use nn.softmax_cross_entropy_with_logits instead.
# (pid=9801)
# (pid=9801) W0417 12:56:32.258388 140635223062272 deprecation_wrapper.py:76] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/autograph/converters/directives.py:116: The name nn.softmax is deprecated. Please use nn.softmax instead.
# (pid=9801)
# Exception in thread ray_import_thread:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/ray/import_thread.py", line 70, in _run
#     msg = import_pubsub_client.get_message()
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
#
# Exception in thread ray_listen_error_messages:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/ray/worker.py", line 1758, in listen_error_messages_raylet
#     msg = worker.error_message_pubsub_client.get_message()
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
#
# Exception in thread ray_print_logs:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 185, in _read_from_socket
#     raise socket.error(SERVER_CLOSED_CONNECTION_ERROR)
# OSError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/ray/worker.py", line 1655, in print_logs
#     msg = pubsub_client.get_message()
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3135, in get_message
#     response = self.parse_response(block=False, timeout=timeout)
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3036, in parse_response
#     return self._execute(connection, connection.read_response)
#   File "/usr/local/lib/python3.5/dist-packages/redis/client.py", line 3013, in _execute
#     return command(*args)
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 637, in read_response
#     response = self._parser.read_response()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 290, in read_response
#     response = self._buffer.readline()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 224, in readline
#     self._read_from_socket()
#   File "/usr/local/lib/python3.5/dist-packages/redis/connection.py", line 199, in _read_from_socket
#     (e.args,))
# redis.exceptions.ConnectionError: Error while reading from socket: ('Connection closed by server.',)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2435             False,
# -> 2436             worker.current_task_id,
#    2437         )
#
# python/ray/_raylet.pyx in ray._raylet.RayletClient.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# Exception: [RayletClient] Raylet connection closed.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f91344f49ea4> in <module>
#       9 # experiment.
#      10 for i in range(10):
# ---> 11     ready_ids, remaining_ids = ray.wait(remaining_ids, num_returns=1)
#      12     accuracy = ray.get(ready_ids[0])
#      13     print("Accuracy is {}".format(accuracy), "Hyperparameter:", hyperparameters)
#
# /usr/local/lib/python3.5/dist-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    2434             timeout_milliseconds,
#    2435             False,
# -> 2436             worker.current_task_id,
#    2437         )
#    2438         return ready_ids, remaining_ids
#
# KeyboardInterrupt:
