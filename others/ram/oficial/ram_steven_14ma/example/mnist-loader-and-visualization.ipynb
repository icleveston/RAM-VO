# %%
from data.augmented_mnist import *
from visualization.data import plot_mnist_images

# %%
(X_train, y_train), (X_test, y_test) = get_mnist(False, False, False)
plot_mnist_images(X_train.reshape(-1, 28, 28), y_train, 10)

# %%
(X_train, y_train), (X_test, y_test) = get_translated_mnist(60, 60)
plot_mnist_images(X_train.reshape(-1, 60, 60), y_train, 10)

# %%
(X_train, y_train), (X_test, y_test) = get_cluttered_translated_mnist(4, 60, 60, 8, 8)
plot_mnist_images(X_train.reshape(-1, 60, 60), y_train, 10)

# %%
(X_train, y_train), (X_test, y_test) = get_cluttered_translated_mnist(8, 100, 100, 8, 8)
plot_mnist_images(X_train.reshape(-1, 100, 100), y_train, 10)
